# %% [markdown]
# # US Software Engineers Analysis with Pandas

# %%
# we start by importing all necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re

# %%
# we read the csv and print the first 5 rows
df = pd.read_csv('expert_data.csv')
df.head()
# Out:
#                                                title  \
# 0                                  Android Developer
# 1                                      Web Developer
# 2                              Sr. Android Developer
# 3                           Junior Software Engineer
# 4  Cloud Engineer (Software Engineer Advanced, Ex...
#
#                             company                    salary  rating  \
# 0                           Shockoe                       NaN     0.0
# 1                      Denios, Inc.  $45,000 - $55,000 a year     0.0
# 2               The Cervantes Group                       NaN     4.1
# 3           Medical Knowledge Group                       NaN     0.0
# 4  Federal Reserve Bank of New York                       NaN     4.1
#
#    review_count      types         location relative_time hires_needed  \
# 0             0  Full-time     Richmond, VA  30+ days ago          NaN
# 1             0  Full-time   Louisville, KY  30+ days ago          ONE
# 2            22  Full-time           Remote    6 days ago     TWO_FOUR
# 3             0  Full-time           Remote    8 days ago          ONE
# 4           548  Full-time  Kansas City, MO    2 days ago          NaN
#
#   hires_needed_exact  ...  indeed_applyable        ad_id remote_location  \
# 0                NaN  ...             False          NaN           False
# 1                  1  ...              True  370154371.0           False
# 2                  2  ...              True          NaN           False
# 3                  1  ...              True  368864426.0           False
# 4                NaN  ...             False          NaN           False
#
#    source_id hiring_event_job  indeed_apply_enabled job_location_postal  \
# 0   11706594            False                 False                 NaN
# 1   11468052            False                  True             40219.0
# 2    9570478            False                  True                 NaN
# 3     501562            False                  True                 NaN
# 4       1439            False                 False                 NaN
#
#                    company_overview_link      activity_date  location_extras
# 0                                    NaN                NaN              NaN
# 1                                    NaN  Active 2 days ago              NaN
# 2               /cmp/The-Cervantes-Group  Active 3 days ago              NaN
# 3                                    NaN  Active 3 days ago              NaN
# 4  /cmp/Federal-Reserve-Bank-of-New-York                NaN              NaN
#
# [5 rows x 29 columns]

# %%
# Get information about columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58433 entries, 0 to 58432
# Data columns (total 29 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   title                  58433 non-null  object
#  1   company                58430 non-null  object
#  2   salary                 18103 non-null  object
#  3   rating                 58433 non-null  float64
#  4   review_count           58433 non-null  int64
#  5   types                  42577 non-null  object
#  6   location               58433 non-null  object
#  7   relative_time          58433 non-null  object
#  8   hires_needed           11857 non-null  object
#  9   hires_needed_exact     18439 non-null  object
#  10  urgently_hiring        58433 non-null  bool
#  11  remote_work_model      22804 non-null  object
#  12  snippet                58425 non-null  object
#  13  dradis_job             58433 non-null  bool
#  14  link                   58433 non-null  object
#  15  new_job                58433 non-null  bool
#  16  job_link               58433 non-null  object
#  17  sponsored              58433 non-null  bool
#  18  featured_employer      58433 non-null  bool
#  19  indeed_applyable       58433 non-null  bool
#  20  ad_id                  23626 non-null  float64
#  21  remote_location        58433 non-null  bool
#  22  source_id              58433 non-null  int64
#  23  hiring_event_job       58433 non-null  bool
#  24  indeed_apply_enabled   58433 non-null  bool
#  25  job_location_postal    26121 non-null  float64
#  26  company_overview_link  36295 non-null  object
#  27  activity_date          13801 non-null  object
#  28  location_extras        11450 non-null  object
# dtypes: bool(9), float64(3), int64(2), object(15)
# memory usage: 9.4+ MB

# %%
# Get statistical data about the dataset
df.describe()
# Out:
#              rating   review_count         ad_id     source_id  \
# count  58433.000000   58433.000000  2.362600e+04  5.843300e+04
# mean       2.565040    1604.469050  3.376991e+08  6.605754e+06
# std        1.832927    5894.934474  8.307966e+07  7.333885e+06
# min        0.000000       0.000000  9.826900e+04  1.700000e+01
# 25%        0.000000       0.000000  3.616971e+08  1.571000e+04
# 50%        3.500000      14.000000  3.694296e+08  3.370807e+06
# 75%        4.000000     624.000000  3.716887e+08  1.307450e+07
# max        5.000000  223345.000000  3.725696e+08  2.077308e+07
#
#        job_location_postal
# count         26121.000000
# mean          52579.873627
# std           33371.519030
# min             603.000000
# 25%           20877.000000
# 50%           53122.000000
# 75%           87124.000000
# max           99901.000000

# %%
for i in df.columns:
    print(i, df[i].value_counts())
# Out:
# title title
# Senior Software Engineer                           2957
# Software Engineer                                  2833
# Sr. Software Engineer                               637
# DevOps Engineer                                     595
# Software Developer                                  538
#                                                    ...
# ETL Software Engineer                                 1
# DevOps Software Engineer II                           1
# Associate Director, Software Engineering - Cart       1
# DevOps Engineer ( manufacturing, production )         1
# Senior Engineer II-Software                           1
# Name: count, Length: 17633, dtype: int64
# company company
# Indeed                            1166
# Capital One                       1063
# Liberty Mutual Insurance           808
# VMware                             629
# VMware Engineering                 491
#                                   ...
# Clockshark                           1
# Virtual Benefits Administrator       1
# Trust Consulting Services Inc.       1
# GoCanvas                             1
# SIDEARM Sports                       1
# Name: count, Length: 10998, dtype: int64
# salary salary
# $132,000 - $192,000 a year    505
# $109,000 - $159,000 a year    322
# $90,000 - $120,000 a year     282
# $1,000 - $6,000 a month       231
# From $100,000 a year          229
#                              ...
# From $104,000 a year            1
# $12 - $17 an hour               1
# $72,122 - $159,911 a year       1
# $108,211 - $175,578 a year      1
# $75,983 - $171,636 a year       1
# Name: count, Length: 2040, dtype: int64
# rating rating
# 0.0    18865
# 3.9     4963
# 4.0     4127
# 3.7     3300
# 3.6     2973
# 3.8     2885
# 4.1     2745
# 4.3     2531
# 3.5     2266
# 5.0     1893
# 4.2     1840
# 3.3     1521
# 3.0     1487
# 3.4     1356
# 3.2     1034
# 4.5      603
# 3.1      584
# 2.9      496
# 2.8      392
# 4.8      337
# 4.4      316
# 2.7      275
# 4.7      259
# 1.0      235
# 2.0      211
# 2.6      193
# 4.6      192
# 2.5      164
# 2.4       97
# 2.3       80
# 1.5       65
# 4.9       65
# 2.2       43
# 1.9       17
# 2.1       10
# 1.7        7
# 1.8        4
# 1.3        1
# 1.4        1
# Name: count, dtype: int64
# review_count review_count
# 0       18865
# 1        2531
# 4        1362
# 2        1323
# 9384     1200
#         ...
# 341         1
# 3710        1
# 2251        1
# 694         1
# 574         1
# Name: count, Length: 1050, dtype: int64
# types types
# Full-time                                                37930
# Full-time, Contract                                       2231
# Contract                                                   997
# Full-time, Part-time, Contract                             563
# Full-time, Part-time                                       213
# Part-time                                                  205
# Part-time, Contract                                        161
# Full-time, Temporary                                        79
# Temporary                                                   43
# Full-time, Internship                                       31
# Full-time, Temporary, Contract                              24
# Internship                                                  24
# Full-time, Part-time, Temporary, Contract                   14
# Part-time, Temporary                                        13
# Full-time, Part-time, Contract, Internship                   9
# Part-time, Internship                                        7
# Full-time, Part-time, Temporary, Contract, Internship        6
# Full-time, Part-time, Internship                             6
# Full-time, Part-time, Temporary                              5
# Full-time, Temporary, Contract, Internship                   5
# Part-time, Temporary, Contract, Internship                   3
# Part-time, Temporary, Contract                               3
# Part-time, Temporary, Internship                             2
# Full-time, Contract, Internship                              2
# Full-time, Part-time, Temporary, Internship                  1
# Name: count, dtype: int64
# location location
# Remote               6730
# New York, NY         2529
# San Francisco, CA    1996
# Austin, TX           1971
# Boston, MA           1300
#                      ...
# Sykesville, MD          1
# Lewis Center, OH        1
# Rockwell, TX            1
# Stafford, VA            1
# Yuba City, CA           1
# Name: count, Length: 2240, dtype: int64
# relative_time relative_time
# 30+ days ago    23021
# 2 days ago       3012
# 1 day ago        2636
# Today            2535
# 5 days ago       2318
# 6 days ago       2027
# 8 days ago       1764
# 9 days ago       1710
# 7 days ago       1621
# 13 days ago      1559
# 14 days ago      1377
# 12 days ago      1285
# 15 days ago      1238
# 21 days ago      1148
# 27 days ago      1073
# 23 days ago      1047
# 20 days ago      1035
# 28 days ago       956
# 3 days ago        939
# 19 days ago       849
# 26 days ago       837
# 22 days ago       795
# 29 days ago       780
# Just posted       646
# 30 days ago       567
# 4 days ago        378
# 11 days ago       291
# 10 days ago       255
# 16 days ago       241
# 24 days ago       152
# 18 days ago       149
# 25 days ago       106
# 17 days ago        86
# Name: count, dtype: int64
# hires_needed hires_needed
# ONE               7177
# TWO_FOUR          3141
# FIVE_TEN           736
# RECURRING_HIRE     550
# TEN_PLUS           253
# Name: count, dtype: int64
# hires_needed_exact hires_needed_exact
# 1                 12261
# 2                  2915
# 3                  1010
# RECURRING_HIRE      743
# 5                   538
# 4                   318
# TEN_PLUS            318
# 10                  167
# 6                    96
# 8                    51
# 7                    16
# 9                     6
# Name: count, dtype: int64
# urgently_hiring urgently_hiring
# False    50874
# True      7559
# Name: count, dtype: int64
# remote_work_model remote_work_model
# REMOTE_ALWAYS             17556
# REMOTE_COVID_TEMPORARY     5248
# Name: count, dtype: int64
# snippet snippet
# Buddy is seeking an independent contractor who can spearhead sales and lead-generation activities, including prospecting, outreach, qualifying leads, and…            331
# Lead a portfolio of diverse technology projects and a team of developers with deep experience in machine learning, distributed microservices, and full stack…         230
# Contributed to open source ML software.\n Deliver ML software models and components that solve real-world business problems, while working in collaboration with…     196
# You execute well with a high degree of individual ownership, but are also adept working as part of a team.\n You love working in a data-driven and customer-first…    129
# Experience of building high quality software in Java and Python.\n Experience building enterprise-level software with a focus on performance, scalability, and…       113
#                                                                                                                                                                      ...
# This Software Engineering position is focused design, development, integration and operation of RF Hardware/Software controlled instrumentation systems for…            1
# Familiarity with Confluence and Jira software applications.\n The Senior Web Developer/Designer will be a key member of the program’s UI/UX team and coordinate…        1
# Build and grow a team of exceptional software engineers and technical leaders.\n 12+ years of software engineering experience.                                          1
# NET, Web API, C#, SQL Server, SSIS, Linux.                                                                                                                              1
# Develop software and architectures to accelerate machine learning on FPGAs.\n Develop other software tools to support our efforts, applying graph algorithms,…          1
# Name: count, Length: 25524, dtype: int64
# dradis_job dradis_job
# False    37888
# True     20545
# Name: count, dtype: int64
# link link
# /rc/clk?jk=8ac8939f4510ebb0&fccid=b6b32194966775c7&vjs=3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            1
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           1
# Name: count, Length: 58433, dtype: int64
# sponsored sponsored
# False    34807
# True     23626
# Name: count, dtype: int64
# featured_employer featured_employer
# False    54950
# True      3483
# Name: count, dtype: int64
# indeed_applyable indeed_applyable
# False    29431
# True     29002
# Name: count, dtype: int64
# ad_id ad_id
# 370961107.0    420
# 8974242.0      408
# 364420058.0    368
# 364420135.0    364
# 364767266.0    348
#               ...
# 307669793.0      1
# 365070631.0      1
# 363291263.0      1
# 371780917.0      1
# 365980946.0      1
# Name: count, Length: 1405, dtype: int64
# remote_location remote_location
# False    58433
# Name: count, dtype: int64
# source_id source_id
# 3465        1635
# 4780        1200
# 15530       1166
# 213          808
# 12814        536
#             ...
# 2564573        1
# 34387          1
# 18421055       1
# 16370554       1
# 35957          1
# Name: count, Length: 11168, dtype: int64
# hiring_event_job hiring_event_job
# False    58433
# Name: count, dtype: int64
# indeed_apply_enabled indeed_apply_enabled
# False    29431
# True     29002
# Name: count, dtype: int64
# job_location_postal job_location_postal
# 95131.0    363
# 98052.0    263
# 94103.0    261
# 94086.0    255
# 94105.0    186
#           ...
# 14605.0      1
# 87106.0      1
# 23285.0      1
# 72202.0      1
# 90405.0      1
# Name: count, Length: 3061, dtype: int64
# company_overview_link company_overview_link
# /cmp/Capital-One                        1200
# /cmp/Indeed                             1166
# /cmp/Vmware                             1134
# /cmp/Liberty-Mutual-Insurance            808
# /cmp/Salesforce                          432
#                                         ...
# /cmp/Belshaw-Adamatic-Bakery-Group-1       1
# /cmp/Customer-Value-Partners               1
# /cmp/Sticker-Mule                          1
# /cmp/Cdata-Software                        1
# /cmp/Sidearm-Sports                        1
# Name: count, Length: 5133, dtype: int64
# activity_date activity_date
# Active 3 days ago     6459
# Active 2 days ago     2526
# Active 6 days ago     1053
# Active 7 days ago      966
# Active 8 days ago      560
# Active 5 days ago      508
# Active 4 days ago      338
# Active 9 days ago      209
# Active 15 days ago     187
# Active 10 days ago     180
# Active 16 days ago     149
# Active 14 days ago     114
# Active 13 days ago      76
# Active 20 days ago      74
# Active 28 days ago      60
# Active 23 days ago      57
# Active 21 days ago      55
# Active 12 days ago      54
# 30+ days ago            49
# Active 17 days ago      32
# Active 24 days ago      24
# Active 22 days ago      20
# Active 29 days ago      20
# Active 27 days ago      13
# Active 11 days ago      10
# Active 19 days ago       5
# Active 18 days ago       2
# Active 25 days ago       1
# Name: count, dtype: int64
# location_extras location_extras
# Downtown            1246
# Overlake             281
# North Valley         279
# North San Jose       239
# South of Market      217
#                     ...
# Central Richmond       1
# Boyle Heights          1
# Spenard                1
# Lower Queen Anne       1
# MLK 183                1
# Name: count, Length: 976, dtype: int64

# %% [markdown]
# ### Objective 1

# %%
df["title"].value_counts()[:3]
# Out:
# title
# Senior Software Engineer    2957
# Software Engineer           2833
# Sr. Software Engineer        637
# Name: count, dtype: int64

# %%
remote = df[df["location"] == "Remote"]
not_remote = df[df["location"] != "Remote"]
len(remote),len(not_remote)
# Out:
# (6730, 51703)

# %%
print("Comparison Ratings remote and not-remote jobs")
print(f"Median Rating, Remote: {remote.rating.median():.2f}, Not-Remote: {not_remote.rating.median():.2f}")
print(f"Mean Rating, Remote: {remote.rating.mean():.2f}, Not-Remote: {not_remote.rating.mean():.2f}")
# Out:
# Comparison Ratings remote and not-remote jobs
# Median Rating, Remote: 2.90, Not-Remote: 3.60
# Mean Rating, Remote: 2.02, Not-Remote: 2.64

# %%
remote_distribution = (remote['rating'].map(lambda x: round(x, 0)).value_counts(normalize=True)).sort_index()
remote_distribution
# Calculate percentage distribution for not_remote dataframe
not_remote_distribution = (not_remote['rating'].map(lambda x: round(x, 0)).value_counts(normalize=True)).sort_index()

f, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))
ax1.bar(remote_distribution.index, remote_distribution.values)
ax1.set_title('Remote')
ax2.set_title("Not Remote")
ax1.set_xlabel('Rating')
ax2.set_xlabel('Rating')
ax1.set_ylabel('Percentage distribution')
ax2.bar(not_remote_distribution.index, not_remote_distribution.values)
# Out:
# <BarContainer object of 6 artists>

# %% [markdown]
# It is difficult to evaluate the result, because there are much more NaN values in the remote dataset. We can see that more people voted in the not remote dataset and that most people who voted in both datasets gave the rating 4. The average and median rating is higher in the not remote dataset.

# %%
remote.salary.value_counts()
# Out:
# salary
# $132,000 - $192,000 a year    171
# $110,000 - $150,000 a year     94
# $90,000 - $120,000 a year      93
# $109,000 - $159,000 a year     82
# $120,000 - $150,000 a year     82
#                              ...
# $39,519 - $82,505 a year        1
# $22,000 - $42,000 a year        1
# $45 - $65 an hour               1
# $188,000 - $272,000 a year      1
# $80 - $120 an hour              1
# Name: count, Length: 612, dtype: int64

# %% [markdown]
# 1. We have to make a few assumptions about the distribution. If a range is given then we calculate the mean. If it's a hourly salary then we multiply it by 40 * 52 since we assume the person works for 40 hours a week and a year consists of 52 weeks.
# 2. We have to code this requirements since we need integers or floats to calculate the average salary

# %%
remote.salary.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 6730 entries, 2 to 58423
# Series name: salary
# Non-Null Count  Dtype
# --------------  -----
# 4113 non-null   object
# dtypes: object(1)
# memory usage: 105.2+ KB

# %%
not_remote.salary.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 51703 entries, 0 to 58432
# Series name: salary
# Non-Null Count  Dtype
# --------------  -----
# 13990 non-null  object
# dtypes: object(1)
# memory usage: 807.9+ KB

# %%
data = pd.Series(["$132,000 - $192,000 a year", "$110,000 - $150,000 a year"])

# Define a function to extract numbers from a string
def extract_numbers(text):
    text = str(text)
    text = text.replace(",", "")
    numbers = re.findall(r'\d+', text)
    return [int(number) for number in numbers]

def formatter(pd_series):
    # Apply the function to each element in the Series to get the sublists of numbers
    sublists = pd_series.apply(extract_numbers)

    # Calculate the mean for each sublist
    means = sublists.apply(lambda sublist: sum(sublist) / len(sublist) if len(sublist) > 0 else np.nan) 
    return means
remote.salary.dropna(inplace=True)
not_remote.salary.dropna(inplace=True)

salaries_remote = formatter(remote.salary)
salaries_not_remote = formatter(not_remote.salary)
print(f"Average Salaries, Remote: {salaries_remote.mean():.2f}, Not Remote: {salaries_not_remote.mean():.2f}")
# Out:
# Average Salaries, Remote: 107144.57, Not Remote: 95191.45
# /var/folders/fh/jv92z4dx5j9g6t17kwcrwbr40000gn/T/ipykernel_44310/316573700.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   remote.salary.dropna(inplace=True)
# /var/folders/fh/jv92z4dx5j9g6t17kwcrwbr40000gn/T/ipykernel_44310/316573700.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   not_remote.salary.dropna(inplace=True)
