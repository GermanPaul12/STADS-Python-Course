# %% [markdown]
# # Data Analysis Refresher
#
# ## Context
# The Customer Shopping Preferences Dataset offers valuable insights into consumer behavior and purchasing patterns. Understanding customer preferences and trends is critical for businesses to tailor their products, marketing strategies, and overall customer experience. This dataset captures a wide range of customer attributes including age, gender, purchase history, preferred payment methods, frequency of purchases, and more. Analyzing this data can help businesses make informed decisions, optimize product offerings, and enhance customer satisfaction. The dataset stands as a valuable resource for businesses aiming to align their strategies with customer needs and preferences. It's important to note that this dataset is a Synthetic Dataset Created for Beginners to learn more about Data Analysis and Machine Learning.
#
# ## Content
# This dataset encompasses various features related to customer shopping preferences, gathering essential information for businesses seeking to enhance their understanding of their customer base. The features include customer age, gender, purchase amount, preferred payment methods, frequency of purchases, and feedback ratings. Additionally, data on the type of items purchased, shopping frequency, preferred shopping seasons, and interactions with promotional offers is included. With a collection of 3900 records, this dataset serves as a foundation for businesses looking to apply data-driven insights for better decision-making and customer-centric strategies.
#
# Dataset Glossary (Column-wise)
# - Customer ID - Unique identifier for each customer
# - Age - Age of the customer
# - Gender - Gender of the customer (Male/Female)
# - Item Purchased - The item purchased by the customer
# - Category - Category of the item purchased
# - Purchase Amount (USD) - The amount of the purchase in USD
# - Location - Location where the purchase was made
# - Size - Size of the purchased item
# - Color - Color of the purchased item
# - Season - Season during which the purchase was made
# - Review Rating - Rating given by the customer for the purchased item
# - Subscription Status - Indicates if the customer has a subscription (Yes/No)
# - Shipping Type - Type of shipping chosen by the customer
# - Discount Applied - Indicates if a discount was applied to the purchase (Yes/No)
# - Promo Code Used - Indicates if a promo code was used for the purchase (Yes/No)
# - Previous Purchases - The total count of transactions concluded by the customer at the store, excluding the ongoing transaction
# - Payment Method - Customer's most preferred payment method
# - Frequency of Purchases - Frequency at which the customer makes purchases (e.g., Weekly, Fortnightly, Monthly)

# %% [markdown]
# # Tasks
#
# 1.1 Import pandas as pd \
# 1.2 Read the csv as DataFrame in Pandas \
# 1.3 Show the first five rows

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_csv("shopping.csv")
df.head()
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
#    Shipping Type Discount Applied Promo Code Used  Previous Purchases  \
# 0        Express              Yes             Yes                  14
# 1        Express              Yes             Yes                   2
# 2  Free Shipping              Yes             Yes                  23
# 3   Next Day Air              Yes             Yes                  49
# 4  Free Shipping              Yes             Yes                  31
#
#   Payment Method Frequency of Purchases
# 0          Venmo            Fortnightly
# 1           Cash            Fortnightly
# 2    Credit Card                 Weekly
# 3         PayPal                 Weekly
# 4         PayPal               Annually

# %% [markdown]
# 1.4 Show the data type of each column and display the number of rows and columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Customer ID             3900 non-null   int64
#  1   Age                     3900 non-null   int64
#  2   Gender                  3900 non-null   object
#  3   Item Purchased          3900 non-null   object
#  4   Category                3900 non-null   object
#  5   Purchase Amount (USD)   3900 non-null   int64
#  6   Location                3900 non-null   object
#  7   Size                    3900 non-null   object
#  8   Color                   3900 non-null   object
#  9   Season                  3900 non-null   object
#  10  Review Rating           3900 non-null   float64
#  11  Subscription Status     3900 non-null   object
#  12  Shipping Type           3900 non-null   object
#  13  Discount Applied        3900 non-null   object
#  14  Promo Code Used         3900 non-null   object
#  15  Previous Purchases      3900 non-null   int64
#  16  Payment Method          3900 non-null   object
#  17  Frequency of Purchases  3900 non-null   object
# dtypes: float64(1), int64(4), object(13)
# memory usage: 548.6+ KB

# %%
f"Number of rows {df.shape[0]} and {df.shape[1]} columns"
# Out:
# 'Number of rows 3900 and 18 columns'

# %% [markdown]
# 1.5 Save the distribution (how many males and females are featured in the dataset) of the column 'Gender' in a variable named 'gender'

# %%
gender = df.Gender.value_counts()

# %% [markdown]
# 1.6 Display gender

# %%
print(gender)
# Out:
# Male      2652
# Female    1248
# Name: Gender, dtype: int64

# %% [markdown]
# 1.7 Save the mean rating in a variable 'mean_rating' and display it

# %%
mean_rating = df["Review Rating"].mean()
print(mean_rating)
# Out:
# 3.7499487179487176

# %% [markdown]
# 1.8 Save all rows where the Purchase Amount is less than 21 dollars in a variable named `cheap_deals` and print `cheap_deals`

# %%
cheap_deals = df[df["Purchase Amount (USD)"] < 21]
cheap_deals
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 5               6   46    Male       Sneakers     Footwear
# 26             27   38    Male        Jewelry  Accessories
# 52             53   42    Male        T-shirt     Clothing
# 255           256   43    Male          Scarf  Accessories
# 294           295   70    Male          Skirt     Clothing
# 341           342   20    Male            Hat  Accessories
# 444           445   48    Male          Dress     Clothing
# 507           508   65    Male         Shorts     Clothing
# 508           509   27    Male        Jewelry  Accessories
# 586           587   45    Male         Hoodie     Clothing
# 637           638   21    Male        Sweater     Clothing
# 638           639   53    Male        Sandals     Footwear
# 800           801   32    Male          Socks     Clothing
# 850           851   68    Male          Shoes     Footwear
# 867           868   37    Male         Jacket    Outerwear
# 977           978   20    Male           Belt  Accessories
# 1065         1066   59    Male        T-shirt     Clothing
# 1124         1125   42    Male        Sweater     Clothing
# 1215         1216   66    Male         Blouse     Clothing
# 1403         1404   26    Male       Backpack  Accessories
# 1505         1506   46    Male           Belt  Accessories
# 1704         1705   56    Male       Sneakers     Footwear
# 1723         1724   70    Male          Scarf  Accessories
# 1755         1756   56    Male           Belt  Accessories
# 1795         1796   68    Male          Jeans     Clothing
# 1893         1894   28    Male          Dress     Clothing
# 1973         1974   24    Male          Skirt     Clothing
# 2045         2046   31    Male        Jewelry  Accessories
# 2164         2165   42    Male        Sandals     Footwear
# 2209         2210   42    Male        Sandals     Footwear
# 2301         2302   37    Male          Pants     Clothing
# 2373         2374   37    Male         Hoodie     Clothing
# 2438         2439   32    Male          Jeans     Clothing
# 2561         2562   32    Male         Hoodie     Clothing
# 2579         2580   65    Male         Blouse     Clothing
# 2652         2653   23  Female         Shorts     Clothing
# 2696         2697   57  Female           Coat    Outerwear
# 2798         2799   52  Female         Hoodie     Clothing
# 2893         2894   69  Female           Belt  Accessories
# 2989         2990   46  Female           Belt  Accessories
# 3083         3084   22  Female          Pants     Clothing
# 3129         3130   60  Female        Sandals     Footwear
# 3130         3131   52  Female          Pants     Clothing
# 3251         3252   25  Female           Coat    Outerwear
# 3274         3275   46  Female        Sweater     Clothing
# 3452         3453   26  Female         Jacket    Outerwear
# 3529         3530   55  Female        T-shirt     Clothing
# 3638         3639   40  Female       Backpack  Accessories
# 3653         3654   67  Female           Coat    Outerwear
# 3793         3794   62  Female     Sunglasses  Accessories
# 3854         3855   57  Female        T-shirt     Clothing
# 3880         3881   42  Female          Shirt     Clothing
#
#       Purchase Amount (USD)       Location Size      Color  Season  \
# 5                        20        Wyoming    M      White  Summer
# 26                       20         Nevada    M        Red  Spring
# 52                       20         Alaska    M      Green  Summer
# 255                      20       Maryland    M   Charcoal  Spring
# 294                      20     New Jersey    M       Gold  Spring
# 341                      20           Utah    S       Blue  Summer
# 444                      20     California    M        Red  Summer
# 507                      20          Maine    M    Magenta  Spring
# 508                      20       Illinois    S     Yellow  Winter
# 586                      20      Wisconsin    S       Blue  Winter
# 637                      20      Tennessee    M       Cyan  Winter
# 638                      20       Maryland    S       Blue  Summer
# 800                      20           Utah    S       Gold  Summer
# 850                      20    Connecticut    L  Turquoise  Winter
# 867                      20       Colorado    M  Turquoise  Spring
# 977                      20     Washington    M      Black  Spring
# 1065                     20        Alabama   XL       Blue  Spring
# 1124                     20           Iowa    M     Orange  Spring
# 1215                     20         Oregon    L       Pink  Winter
# 1403                     20        Georgia    M      Peach  Spring
# 1505                     20   North Dakota    M       Teal  Summer
# 1704                     20          Idaho    M   Lavender  Summer
# 1723                     20       New York   XL       Gold  Spring
# 1755                     20       Delaware   XL   Charcoal  Spring
# 1795                     20      Wisconsin    S     Violet    Fall
# 1893                     20       Delaware    L        Red  Summer
# 1973                     20       Maryland   XL        Red    Fall
# 2045                     20        Georgia    M        Red    Fall
# 2164                     20           Iowa    S      Olive  Winter
# 2209                     20           Utah   XL      Beige  Summer
# 2301                     20          Maine    L  Turquoise  Winter
# 2373                     20       Michigan    M       Gray  Spring
# 2438                     20       Delaware    S       Cyan  Winter
# 2561                     20       New York    L    Magenta  Spring
# 2579                     20      Minnesota    M     Purple  Summer
# 2652                     20       Maryland    L       Cyan  Summer
# 2696                     20   South Dakota    M      White  Spring
# 2798                     20   Rhode Island   XL        Red  Winter
# 2893                     20       Kentucky    S     Orange  Spring
# 2989                     20   Rhode Island   XL       Teal  Summer
# 3083                     20       Illinois    S     Purple  Summer
# 3129                     20       Maryland    S       Cyan  Summer
# 3130                     20        Vermont    M     Yellow  Summer
# 3251                     20         Nevada    M       Gold  Winter
# 3274                     20       Oklahoma    M       Cyan  Spring
# 3452                     20       Oklahoma    M     Indigo  Spring
# 3529                     20        Montana    S     Maroon  Winter
# 3638                     20         Kansas    M      Olive  Spring
# 3653                     20      Minnesota    M       Blue  Spring
# 3793                     20       Delaware    M       Pink    Fall
# 3854                     20        Florida    M      Black  Spring
# 3880                     20  Massachusetts    M        Red  Winter
#
#       Review Rating Subscription Status   Shipping Type Discount Applied  \
# 5               2.9                 Yes        Standard              Yes
# 26              3.6                 Yes    Next Day Air              Yes
# 52              2.6                 Yes   Free Shipping              Yes
# 255             4.2                 Yes   Free Shipping              Yes
# 294             4.6                 Yes    Store Pickup              Yes
# 341             4.6                 Yes    Store Pickup              Yes
# 444             4.3                 Yes    Store Pickup              Yes
# 507             5.0                 Yes    Store Pickup              Yes
# 508             3.7                 Yes    Store Pickup              Yes
# 586             4.9                 Yes  2-Day Shipping              Yes
# 637             3.4                 Yes  2-Day Shipping              Yes
# 638             2.7                 Yes         Express              Yes
# 800             2.6                 Yes   Free Shipping              Yes
# 850             2.6                 Yes    Store Pickup              Yes
# 867             3.1                 Yes   Free Shipping              Yes
# 977             4.6                 Yes         Express              Yes
# 1065            4.1                  No    Store Pickup              Yes
# 1124            4.9                  No         Express              Yes
# 1215            2.6                  No  2-Day Shipping              Yes
# 1403            3.6                  No    Store Pickup              Yes
# 1505            3.0                  No         Express              Yes
# 1704            3.9                  No    Store Pickup               No
# 1723            3.3                  No        Standard               No
# 1755            4.6                  No    Next Day Air               No
# 1795            4.0                  No  2-Day Shipping               No
# 1893            3.7                  No         Express               No
# 1973            4.5                  No        Standard               No
# 2045            4.4                  No         Express               No
# 2164            4.8                  No    Next Day Air               No
# 2209            4.5                  No  2-Day Shipping               No
# 2301            2.9                  No    Next Day Air               No
# 2373            4.9                  No         Express               No
# 2438            3.4                  No         Express               No
# 2561            2.7                  No   Free Shipping               No
# 2579            3.7                  No         Express               No
# 2652            3.3                  No  2-Day Shipping               No
# 2696            4.7                  No   Free Shipping               No
# 2798            4.8                  No    Store Pickup               No
# 2893            3.1                  No   Free Shipping               No
# 2989            4.3                  No  2-Day Shipping               No
# 3083            3.5                  No    Store Pickup               No
# 3129            4.7                  No         Express               No
# 3130            4.5                  No    Store Pickup               No
# 3251            3.7                  No        Standard               No
# 3274            3.9                  No    Store Pickup               No
# 3452            3.7                  No    Next Day Air               No
# 3529            3.9                  No    Next Day Air               No
# 3638            4.6                  No         Express               No
# 3653            3.9                  No    Next Day Air               No
# 3793            4.0                  No        Standard               No
# 3854            4.2                  No   Free Shipping               No
# 3880            3.9                  No   Free Shipping               No
#
#      Promo Code Used  Previous Purchases Payment Method Frequency of Purchases
# 5                Yes                  14          Venmo                 Weekly
# 26               Yes                  13    Credit Card               Annually
# 52               Yes                  26    Credit Card                 Weekly
# 255              Yes                  25     Debit Card               Annually
# 294              Yes                  19    Credit Card         Every 3 Months
# 341              Yes                  40     Debit Card              Bi-Weekly
# 444              Yes                  31     Debit Card               Annually
# 507              Yes                  33     Debit Card            Fortnightly
# 508              Yes                  31         PayPal              Quarterly
# 586              Yes                   9          Venmo               Annually
# 637              Yes                  46           Cash            Fortnightly
# 638              Yes                  41         PayPal                Monthly
# 800              Yes                  20           Cash         Every 3 Months
# 850              Yes                  13          Venmo                Monthly
# 867              Yes                  23  Bank Transfer            Fortnightly
# 977              Yes                  34           Cash              Bi-Weekly
# 1065             Yes                   3         PayPal         Every 3 Months
# 1124             Yes                  40           Cash              Quarterly
# 1215             Yes                  15    Credit Card         Every 3 Months
# 1403             Yes                  20    Credit Card              Bi-Weekly
# 1505             Yes                  39           Cash                Monthly
# 1704              No                  19           Cash         Every 3 Months
# 1723              No                  39         PayPal               Annually
# 1755              No                  45           Cash                Monthly
# 1795              No                   9     Debit Card            Fortnightly
# 1893              No                  10         PayPal            Fortnightly
# 1973              No                   9          Venmo         Every 3 Months
# 2045              No                  26         PayPal              Quarterly
# 2164              No                  46         PayPal              Bi-Weekly
# 2209              No                  44  Bank Transfer              Quarterly
# 2301              No                  21     Debit Card               Annually
# 2373              No                  21     Debit Card         Every 3 Months
# 2438              No                  30          Venmo                 Weekly
# 2561              No                  22     Debit Card              Quarterly
# 2579              No                  40          Venmo                 Weekly
# 2652              No                  46    Credit Card                Monthly
# 2696              No                  12     Debit Card                Monthly
# 2798              No                  37         PayPal                 Weekly
# 2893              No                  44     Debit Card         Every 3 Months
# 2989              No                   6    Credit Card                 Weekly
# 3083              No                  28         PayPal              Quarterly
# 3129              No                  40          Venmo         Every 3 Months
# 3130              No                  34          Venmo         Every 3 Months
# 3251              No                  39          Venmo              Quarterly
# 3274              No                  14           Cash            Fortnightly
# 3452              No                   3          Venmo            Fortnightly
# 3529              No                  43  Bank Transfer                 Weekly
# 3638              No                  50         PayPal              Bi-Weekly
# 3653              No                  39    Credit Card            Fortnightly
# 3793              No                  46  Bank Transfer               Annually
# 3854              No                   4          Venmo               Annually
# 3880              No                  40         PayPal                Monthly

# %% [markdown]
# 1.9 Save all rows where the Purchase Amount is equal to 100 dollars in a variable named `expensive_deals` and print `expensive_deals`

# %%
expensive_deals = df[df["Purchase Amount (USD)"] == 100]
expensive_deals
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 42             43   20    Male           Coat    Outerwear
# 95             96   37    Male       Sneakers     Footwear
# 193           194   36    Male           Belt  Accessories
# 204           205   24    Male       Sneakers     Footwear
# 243           244   25    Male        Jewelry  Accessories
# 248           249   47    Male           Belt  Accessories
# 455           456   54    Male         Blouse     Clothing
# 518           519   24    Male         Blouse     Clothing
# 581           582   32    Male        Sweater     Clothing
# 615           616   67    Male        Sandals     Footwear
# 769           770   52    Male          Socks     Clothing
# 861           862   46    Male          Skirt     Clothing
# 1208         1209   20    Male          Boots     Footwear
# 1300         1301   67    Male        T-shirt     Clothing
# 1405         1406   33    Male          Socks     Clothing
# 1412         1413   25    Male         Shorts     Clothing
# 1421         1422   68    Male          Dress     Clothing
# 1456         1457   59    Male           Coat    Outerwear
# 1479         1480   48    Male           Coat    Outerwear
# 1591         1592   18    Male          Skirt     Clothing
# 1847         1848   46    Male        Sandals     Footwear
# 2071         2072   69    Male         Jacket    Outerwear
# 2214         2215   50    Male           Belt  Accessories
# 2285         2286   34    Male           Belt  Accessories
# 2430         2431   20    Male         Jacket    Outerwear
# 2802         2803   22  Female           Coat    Outerwear
# 2807         2808   56  Female         Hoodie     Clothing
# 2842         2843   28  Female           Coat    Outerwear
# 2958         2959   55  Female          Skirt     Clothing
# 2971         2972   30  Female        Handbag  Accessories
# 2994         2995   69  Female        Sweater     Clothing
# 3028         3029   62  Female          Dress     Clothing
# 3265         3266   40  Female     Sunglasses  Accessories
# 3321         3322   32  Female           Coat    Outerwear
# 3725         3726   18  Female          Dress     Clothing
# 3837         3838   45  Female         Hoodie     Clothing
#
#       Purchase Amount (USD)        Location Size      Color  Season  \
# 42                      100       Tennessee    M      Beige  Spring
# 95                      100        Missouri    L       Pink    Fall
# 193                     100    North Dakota    S     Silver    Fall
# 204                     100         Arizona    M     Yellow    Fall
# 243                     100        Kentucky    M      Olive  Winter
# 248                     100    Pennsylvania    M       Blue  Winter
# 455                     100            Utah   XL       Gold    Fall
# 518                     100          Oregon    M      Beige    Fall
# 581                     100            Iowa   XL   Charcoal  Winter
# 615                     100        Maryland    L      Olive  Summer
# 769                     100        Delaware    M     Silver  Spring
# 861                     100        Virginia   XL      Green  Spring
# 1208                    100       Wisconsin    S        Red  Winter
# 1300                    100   West Virginia    M   Charcoal  Spring
# 1405                    100   New Hampshire    M      Peach  Winter
# 1412                    100        Michigan    M   Charcoal  Summer
# 1421                    100    Pennsylvania    S       Gold  Spring
# 1456                    100         Montana    S      Olive  Spring
# 1479                    100      Washington    L      Black  Spring
# 1591                    100    South Dakota    L       Gold  Winter
# 1847                    100         Arizona   XL       Cyan  Summer
# 2071                    100  South Carolina    S     Yellow    Fall
# 2214                    100           Idaho    L       Gold    Fall
# 2285                    100        Michigan    L       Pink  Summer
# 2430                    100    North Dakota   XL      White  Summer
# 2802                    100          Hawaii    L        Red    Fall
# 2807                    100        Maryland    M   Charcoal  Spring
# 2842                    100         Arizona    L      Green    Fall
# 2958                    100            Ohio    M      Black  Summer
# 2971                    100            Utah    L     Yellow    Fall
# 2994                    100          Nevada    S      White  Winter
# 3028                    100      California    L   Charcoal  Summer
# 3265                    100         Alabama    M      White  Winter
# 3321                    100           Maine    S   Charcoal  Winter
# 3725                    100        Oklahoma    S  Turquoise  Winter
# 3837                    100      New Mexico    M      Green  Spring
#
#       Review Rating Subscription Status   Shipping Type Discount Applied  \
# 42              4.1                 Yes   Free Shipping              Yes
# 95              3.8                 Yes   Free Shipping              Yes
# 193             3.0                 Yes        Standard              Yes
# 204             4.0                 Yes    Store Pickup              Yes
# 243             2.8                 Yes  2-Day Shipping              Yes
# 248             4.8                 Yes         Express              Yes
# 455             3.6                 Yes    Store Pickup              Yes
# 518             2.9                 Yes    Next Day Air              Yes
# 581             2.7                 Yes    Store Pickup              Yes
# 615             2.6                 Yes    Next Day Air              Yes
# 769             4.3                 Yes    Store Pickup              Yes
# 861             3.3                 Yes  2-Day Shipping              Yes
# 1208            2.9                  No  2-Day Shipping              Yes
# 1300            4.5                  No    Next Day Air              Yes
# 1405            2.7                  No    Store Pickup              Yes
# 1412            2.6                  No  2-Day Shipping              Yes
# 1421            3.0                  No        Standard              Yes
# 1456            2.7                  No    Store Pickup              Yes
# 1479            4.0                  No        Standard              Yes
# 1591            2.9                  No    Next Day Air              Yes
# 1847            4.4                  No   Free Shipping               No
# 2071            4.8                  No    Store Pickup               No
# 2214            4.1                  No        Standard               No
# 2285            4.6                  No  2-Day Shipping               No
# 2430            4.3                  No         Express               No
# 2802            3.1                  No    Store Pickup               No
# 2807            4.4                  No  2-Day Shipping               No
# 2842            4.3                  No        Standard               No
# 2958            4.5                  No        Standard               No
# 2971            3.9                  No    Next Day Air               No
# 2994            3.5                  No    Store Pickup               No
# 3028            3.0                  No   Free Shipping               No
# 3265            3.2                  No         Express               No
# 3321            4.3                  No    Next Day Air               No
# 3725            4.4                  No    Next Day Air               No
# 3837            4.8                  No   Free Shipping               No
#
#      Promo Code Used  Previous Purchases Payment Method Frequency of Purchases
# 42               Yes                  15         PayPal               Annually
# 95               Yes                  48         PayPal                Monthly
# 193              Yes                  29          Venmo               Annually
# 204              Yes                  35           Cash              Bi-Weekly
# 243              Yes                   4     Debit Card                Monthly
# 248              Yes                  33         PayPal                 Weekly
# 455              Yes                  50     Debit Card            Fortnightly
# 518              Yes                  16          Venmo         Every 3 Months
# 581              Yes                  12  Bank Transfer         Every 3 Months
# 615              Yes                  23          Venmo               Annually
# 769              Yes                   8         PayPal                Monthly
# 861              Yes                  35    Credit Card         Every 3 Months
# 1208             Yes                   8     Debit Card               Annually
# 1300             Yes                  47    Credit Card         Every 3 Months
# 1405             Yes                  39    Credit Card                Monthly
# 1412             Yes                  43          Venmo               Annually
# 1421             Yes                  24  Bank Transfer            Fortnightly
# 1456             Yes                  30         PayPal         Every 3 Months
# 1479             Yes                   2  Bank Transfer                 Weekly
# 1591             Yes                  24         PayPal               Annually
# 1847              No                  49    Credit Card                 Weekly
# 2071              No                  37         PayPal              Quarterly
# 2214              No                  20     Debit Card                 Weekly
# 2285              No                  38         PayPal         Every 3 Months
# 2430              No                  42           Cash              Quarterly
# 2802              No                  42    Credit Card            Fortnightly
# 2807              No                  10     Debit Card            Fortnightly
# 2842              No                  48     Debit Card              Quarterly
# 2958              No                  28         PayPal                Monthly
# 2971              No                   9         PayPal         Every 3 Months
# 2994              No                  14  Bank Transfer              Quarterly
# 3028              No                   7         PayPal         Every 3 Months
# 3265              No                  28    Credit Card            Fortnightly
# 3321              No                   3          Venmo               Annually
# 3725              No                   2         PayPal               Annually
# 3837              No                  33  Bank Transfer            Fortnightly

# %% [markdown]
# 2.0 Show the Age Column in a Histogram

# %%
df.Age.hist()
# Out:
# <Axes: >

# %% [markdown]
# 2.1 Show the Size Column in a Histogram

# %%
# Method 1 using pandas
df["Size"].value_counts().loc[['S', 'M', 'L', 'XL']].plot.bar()

# df.Size.hist() wouldn't be wrong 
# i just decided for this approach to cahnge order of sizes, 
# since it was mixed (S, L, M, XL) with the hist() approach.
# Out:
# <Axes: >

# %%
# Method 2 using seaborn
ordered_sizes = pd.Categorical(df['Size'], ["S", "M", "L", "XL"]) # only necessary because Size is unordered
sns.histplot(ordered_sizes) # histplot() can be used to create histograms
plt.show() # plt.show() is used to show the plot. 
# If you use Jupyter notebook it wil show the plot without this line

# %% [markdown]
# 2.2 Group the cheap_deals dataset by gender and show the median rating for each group in a barplot

# %%
grouped_by_gender = cheap_deals.groupby("Gender")["Review Rating"].agg("median")
#grouped_by_gender
sns.barplot(x=grouped_by_gender.index, y=grouped_by_gender)
plt.show()

# %% [markdown]
# 2.3 Count for each payment method how many transactions have been made for it. Store the number of transactions in a variable named `payment_method_distribution` and print it

# %%
payment_method_distribution = df["Payment Method"].value_counts()
print(payment_method_distribution)
# Out:
# PayPal           677
# Credit Card      671
# Cash             670
# Debit Card       636
# Venmo            634
# Bank Transfer    612
# Name: Payment Method, dtype: int64

# %% [markdown]
# 2.4 Show the distribution which you calculated in `2.3` in a pie chart

# %%
plt.pie(payment_method_distribution.values, labels=payment_method_distribution.index ,autopct='%.0f%%')
plt.show()
